# %% [markdown]
# # WQP Data Retrieval
#
# WQP Data Retrieval provides an easy way to obtain data points corresponding to a lake from the water quality data portal (https://www.waterqualitydata.us/portal/). <br>
# Given a set of site IDs <i>X</i> that correspond to a single lake, a set of columns of interest <i>Y</i>, and a set of characteristics of interest <i>Z</i>, this script will query WQP (water quality portal) to obtain data for all site IDs in <i>X</i>, then pull out only the columns in <i>Y</i>, then filter the rows based on the characteristics in <i>Z</i>. This will produce a <i>pandas DataFrame</i> with data points.

# %% [markdown]
# ## Function definitions
#
# In this section of notebook, the functions used to obtain data from WQP are defined.<br>
# 1. Function to write contents of csv into list<br>
# 2. Function to fetch data from WQP, given site IDs <i>X</i><br>
# 3. Function to retain columns of interest <i>Y</i> in DataFrame<br>
# 4. Function to filter rows based on characteristics of interest <i>Z</i>
# 5. Function that performs steps (2),(3) and (4) and returns the data of interest

# %%
import pandas as pd
from pywqp import pywqp_client
client_instance = pywqp_client.RESTClient()

# %% [markdown]
# ### Function to write contents of csv into list
#
# This function writes contents of csv file into a list. It takes path to csv file as input argument and writes contents of the csv file into a list.

# %%
def csv_to_list(file_path):
    """
        Writes content of csv into list
        Args:
            file_path (str): String
        Returns:
            contents_list (list)
    """
    df = pd.read_csv(file_path,header=None) 
    contents_list = df[0].tolist()
    return contents_list

# %% [markdown]
# ### Function to fetch data from WQP, given site IDs X
# This function fetches data from the WQP for a given set of site IDs corresponding to a lake using a web service client. It takes path to csv file containing site IDs as input argument, makes a service call and writes the response data into a pandas DataFrame.

# %%
def web_service_call(dict_place,file_path_site_ids):
    """
        Retrieving data from water quality portal using web service client
        Args:
            dict_place (dict): Input dictionary ,file_path_site_ids (str): Input String 
        Returns:
            result_df (pandas DataFrame)
    """
    # Get the site ids
    list_site_ids = csv_to_list(file_path_site_ids)
    site_ids = ';'.join(list_site_ids)
    
    # Preparing the input payload
    verb = 'get'
    host_url = 'http://waterqualitydata.us'
    resource_label = 'result'
    params = {'countrycode': dict_place['country_code'], 'statecode': dict_place['state_code'], 'countycode': dict_place['county_code'],'siteid':site_ids}
    #params = {'countrycode': '', 'statecode': '', 'countycode': '','siteid':site_ids}
    equivalent_url = client_instance.create_rest_url(host_url, resource_label, params, mime_type='text/csv')
    
    # Make the web-service call and get the response into a DataFrame
    result = client_instance.request_wqp_data(verb, host_url, resource_label, params, mime_type='text/csv')
    result_df = client_instance.response_as_pandas_dataframe(result)
    return result_df

# %% [markdown]
# ### Function to retain columns of interest Y in DataFrame
# This function retains only the columns of interest in the given DataFrame. It takes as input DataFrame and path to csv file containing column names and retains only the given columns in DataFrame.

# %%
def format_columns_df(df,file_path_columns):
    """
        Retaining required columns in DataFrame
        Args:
            df: Input pandas dataframe, file_path_columns (str): Input String
        Returns:
            df_drop_cols (pandas DataFrame)
    """
    # Get list of column names from given file path
    columns = csv_to_list(file_path_columns)
    
    # Get the existing columns in DataFrame
    columns_init = df.columns.tolist()
    
    # Check for existence of columns in DataFrame
    if set(columns).issubset(columns_init):
        df_drop_cols = df[columns]
        return df_drop_cols
    else:
        print("Invalid column names present")

# %% [markdown]
# ### Function to filter rows based on characteristics of interest Z
# This function filters rows in the DataFrame based on given characteristics. It takes as input DataFrame and path to csv file containing <i>CharacteristicName</i> values and filters the DataFrame on the given values.

# %%
def filter_df(df,file_path_characteristics):
    """
        Filtering column 'CharacteristicName' of DataFrame
        Args:
            df: Input pandas dataframe, file_path_characteristics (str): Input String
        Returns:
            df_filtered (pandas DataFrame)
    """
    # Get list of column names from given file path
    characteristics = csv_to_list(file_path_characteristics)
    df_filtered = df[df['CharacteristicName'].isin(characteristics)]
    return df_filtered

# %% [markdown]
# ### Function that performs steps (2),(3) and (4) and returns the data of interest
# This function queries WQP (water quality portal) to obtain data for all site IDs, then pulls out only the columns  of interest, then filters the rows based on the characteristics of interest and returns a DataFrame containing the data of interest.
# It takes as input path to csv file containing site IDs, path to csv file containing columns of interest, path to csv file containing characteristics of interest and returns the desired data points.

# %%
def retrieve_data(dict_place,file_path_site_ids,file_path_columns,file_path_characteristics):
    """
        Retrieves data from WQP for desired lake
        Args:
            dict_place (dict): Input dictionary, file_path_site_ids (str): Input pandas dataframe, 
            file_path_columns (str): Input String, file_path_characteristics (str): Input String 
        Returns:
            df_filtered_chars (pandas DataFrame)
    """
    #Fetch data points in a DataFrame for the given site IDs.
    df_with_site_ids = web_service_call(dict_place,file_path_site_ids)

    #Retain the required columns in the DataFrame.
    df_drop_cols = format_columns_df(df_with_site_ids,file_path_columns)

    #Filter the DataFrame based on required characteristics.
    df_filtered_chars = filter_df(df_drop_cols,file_path_characteristics)
    return df_filtered_chars

# %% [markdown]
# ---------------------------

# %% [markdown]
# ## Data Retrieval for Lake Mendota
# In this section, we use the functions defined above to retrieve data points from WQP for Lake Mendota.<br>
# Given to us are the below paths:
# 1. Dictionary of country code, state code and county code
# 2. Path to csv file containing site IDs corresponding to Lake Mendota
# 3. Path to csv file containing columns of interest
# 4. Path to csv file containing characteristics of interest
#
# We obtain a DataFrame containing the data points for Lake Mendota.<br>

# %%
# Arguments for the function retrieve_data
dict_place = {}
dict_place['country_code'] = 'US'
dict_place['state_code'] = 'US:55'
dict_place['county_code'] = 'US:55:025'

file_path_site_ids = '../data/site_ids.csv'
file_path_columns = '../data/columns.csv'
file_path_characteristics = '../data/characteristics.csv'

#Function call to retrive data for Lake Mendota
df = retrieve_data(dict_place,file_path_site_ids,file_path_columns,file_path_characteristics)
# Out:
# C:\ProgramData\Anaconda3\envs\py27\lib\site-packages\ipykernel\__main__.py:11: DtypeWarning: Columns (5,24,25,30,41,47,49,50,58,60) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
df
# Out:
#         ActivityIdentifier ActivityStartDate ActivityStartTime/Time  \
# 1       nwiswi.01.99204088        1992-07-23               14:10:00
# 2       nwiswi.01.99204088        1992-07-23               14:10:00
# 4       nwiswi.01.99204088        1992-07-23               14:10:00
# 6       nwiswi.01.99204088        1992-07-23               14:10:00
# 7       nwiswi.01.99204088        1992-07-23               14:10:00
# 8       nwiswi.01.99204088        1992-07-23               14:10:00
# 9       nwiswi.01.99204088        1992-07-23               14:10:00
# 11      nwiswi.01.99204088        1992-07-23               14:10:00
# 13      nwiswi.01.99204088        1992-07-23               14:10:00
# 14      nwiswi.01.99204088        1992-07-23               14:10:00
# 15      nwiswi.01.99204088        1992-07-23               14:10:00
# 18      nwiswi.01.99204089        1992-07-23               14:15:00
# 19      nwiswi.01.99204089        1992-07-23               14:15:00
# 21      nwiswi.01.99204089        1992-07-23               14:15:00
# 23      nwiswi.01.99204089        1992-07-23               14:15:00
# 24      nwiswi.01.99204089        1992-07-23               14:15:00
# 25      nwiswi.01.99204089        1992-07-23               14:15:00
# 26      nwiswi.01.99204089        1992-07-23               14:15:00
# 27      nwiswi.01.99204089        1992-07-23               14:15:00
# 28      nwiswi.01.99204089        1992-07-23               14:15:00
# 29      nwiswi.01.99204089        1992-07-23               14:15:00
# 32      nwiswi.01.99204089        1992-07-23               14:15:00
# 34      nwiswi.01.99202614        1992-05-08               11:30:00
# 36      nwiswi.01.99202614        1992-05-08               11:30:00
# 38      nwiswi.01.99202614        1992-05-08               11:30:00
# 39      nwiswi.01.99202614        1992-05-08               11:30:00
# 40      nwiswi.01.99202614        1992-05-08               11:30:00
# 41      nwiswi.01.99202614        1992-05-08               11:30:00
# 42      nwiswi.01.99202614        1992-05-08               11:30:00
# 43      nwiswi.01.99202614        1992-05-08               11:30:00
# ...                    ...               ...                    ...
# 18863  WIDNR_WQX-116000921        2014-06-12               07:00:00
# 18878  WIDNR_WQX-116001066        2014-07-07               15:12:00
# 18879  WIDNR_WQX-116001076        2014-07-07               15:15:00
# 18896  WIDNR_WQX-116001275        2014-08-04               11:24:00
# 18897  WIDNR_WQX-116001280        2014-08-04               07:00:00
# 18916  WIDNR_WQX-116001459        2014-09-05               08:30:00
# 18917  WIDNR_WQX-116001464        2014-09-05               09:46:00
# 18918  WIDNR_WQX-116001467        2014-09-05               09:46:00
# 18919  WIDNR_WQX-116001467        2014-09-05               09:46:00
# 18920  WIDNR_WQX-116001467        2014-09-05               09:46:00
# 19069    WIDNR_WQX-1694737        2005-01-12               13:45:00
# 19070    WIDNR_WQX-1694737        2005-01-12               13:45:00
# 19093    WIDNR_WQX-1696145        2005-01-12               13:45:00
# 19094    WIDNR_WQX-1696145        2005-01-12               13:45:00
# 19095    WIDNR_WQX-1696145        2005-01-12               13:45:00
# 19096    WIDNR_WQX-1696145        2005-01-12               13:45:00
# 19098    WIDNR_WQX-1696145        2005-01-12               13:45:00
# 19106  WIDNR_WQX-116000865        2014-06-05               19:15:00
# 19107  WIDNR_WQX-116001036        2014-07-01               19:20:00
# 19108  WIDNR_WQX-116001370        2014-08-06               19:30:00
# 19109  WIDNR_WQX-116001479        2014-09-03               06:45:00
# 19110  WIDNR_WQX-116000845        2014-06-03               14:00:00
# 19111  WIDNR_WQX-116001071        2014-07-05               11:30:00
# 19112  WIDNR_WQX-116001360        2014-08-07               11:00:00
# 19113  WIDNR_WQX-116001494        2014-09-05               08:30:00
# 20190  WIDNR_WQX-116000840        2014-06-03               08:55:00
# 20191  WIDNR_WQX-116001046        2014-07-02               13:45:00
# 20192  WIDNR_WQX-116001300        2014-08-01               08:55:00
# 20193  WIDNR_WQX-116001245        2014-08-04               11:30:00
# 20194  WIDNR_WQX-116001454        2014-09-08               12:40:00
#
#       ActivityStartTime/TimeZoneCode ActivityEndDate ActivityEndTime/Time  \
# 1                                CDT             NaN                  NaN
# 2                                CDT             NaN                  NaN
# 4                                CDT             NaN                  NaN
# 6                                CDT             NaN                  NaN
# 7                                CDT             NaN                  NaN
# 8                                CDT             NaN                  NaN
# 9                                CDT             NaN                  NaN
# 11                               CDT             NaN                  NaN
# 13                               CDT             NaN                  NaN
# 14                               CDT             NaN                  NaN
# 15                               CDT             NaN                  NaN
# 18                               CDT             NaN                  NaN
# 19                               CDT             NaN                  NaN
# 21                               CDT             NaN                  NaN
# 23                               CDT             NaN                  NaN
# 24                               CDT             NaN                  NaN
# 25                               CDT             NaN                  NaN
# 26                               CDT             NaN                  NaN
# 27                               CDT             NaN                  NaN
# 28                               CDT             NaN                  NaN
# 29                               CDT             NaN                  NaN
# 32                               CDT             NaN                  NaN
# 34                               CDT             NaN                  NaN
# 36                               CDT             NaN                  NaN
# 38                               CDT             NaN                  NaN
# 39                               CDT             NaN                  NaN
# 40                               CDT             NaN                  NaN
# 41                               CDT             NaN                  NaN
# 42                               CDT             NaN                  NaN
# 43                               CDT             NaN                  NaN
# ...                              ...             ...                  ...
# 18863                            CDT      2014-06-12             07:00:00
# 18878                            CDT      2014-07-07             15:12:00
# 18879                            CDT      2014-07-07             15:15:00
# 18896                            CDT      2014-08-04             11:24:00
# 18897                            CDT      2014-08-04             07:00:00
# 18916                            CDT      2014-09-05             08:30:00
# 18917                            CDT      2014-09-05             09:46:00
# 18918                            CDT      2014-09-05             09:46:00
# 18919                            CDT      2014-09-05             09:46:00
# 18920                            CDT      2014-09-05             09:46:00
# 19069                            CST             NaN                  NaN
# 19070                            CST             NaN                  NaN
# 19093                            CST             NaN                  NaN
# 19094                            CST             NaN                  NaN
# 19095                            CST             NaN                  NaN
# 19096                            CST             NaN                  NaN
# 19098                            CST             NaN                  NaN
# 19106                            CDT      2014-06-05             19:15:00
# 19107                            CDT      2014-07-01             19:20:00
# 19108                            CDT      2014-08-06             19:30:00
# 19109                            CDT      2014-09-03             06:45:00
# 19110                            CDT      2014-06-03             14:00:00
# 19111                            CDT      2014-07-05             11:30:00
# 19112                            CDT      2014-08-07             11:00:00
# 19113                            CDT      2014-09-05             08:30:00
# 20190                            CDT      2014-06-03             08:55:00
# 20191                            CDT      2014-07-02             13:45:00
# 20192                            CDT      2014-08-01             08:55:00
# 20193                            CDT      2014-08-04             11:30:00
# 20194                            CDT      2014-09-08             12:40:00
#
#       ActivityEndTime/TimeZoneCode  ActivityDepthHeightMeasure/MeasureValue  \
# 1                              NaN                                      1.5
# 2                              NaN                                      1.5
# 4                              NaN                                      1.5
# 6                              NaN                                      1.5
# 7                              NaN                                      1.5
# 8                              NaN                                      1.5
# 9                              NaN                                      1.5
# 11                             NaN                                      1.5
# 13                             NaN                                      1.5
# 14                             NaN                                      1.5
# 15                             NaN                                      1.5
# 18                             NaN                                     80.5
# 19                             NaN                                     80.5
# 21                             NaN                                     80.5
# 23                             NaN                                     80.5
# 24                             NaN                                     80.5
# 25                             NaN                                     80.5
# 26                             NaN                                     80.5
# 27                             NaN                                     80.5
# 28                             NaN                                     80.5
# 29                             NaN                                     80.5
# 32                             NaN                                     80.5
# 34                             NaN                                      NaN
# 36                             NaN                                      NaN
# 38                             NaN                                      NaN
# 39                             NaN                                      NaN
# 40                             NaN                                      NaN
# 41                             NaN                                      NaN
# 42                             NaN                                      NaN
# 43                             NaN                                      NaN
# ...                            ...                                      ...
# 18863                          CDT                                      NaN
# 18878                          CDT                                      NaN
# 18879                          CDT                                      NaN
# 18896                          CDT                                      NaN
# 18897                          CDT                                      NaN
# 18916                          CDT                                      NaN
# 18917                          CDT                                      NaN
# 18918                          CDT                                      NaN
# 18919                          CDT                                      NaN
# 18920                          CDT                                      NaN
# 19069                          NaN                                      NaN
# 19070                          NaN                                      NaN
# 19093                          NaN                                      NaN
# 19094                          NaN                                      NaN
# 19095                          NaN                                      NaN
# 19096                          NaN                                      NaN
# 19098                          NaN                                      NaN
# 19106                          CDT                                      NaN
# 19107                          CDT                                      NaN
# 19108                          CDT                                      NaN
# 19109                          CDT                                      NaN
# 19110                          CDT                                      NaN
# 19111                          CDT                                      NaN
# 19112                          CDT                                      NaN
# 19113                          CDT                                      NaN
# 20190                          CDT                                      NaN
# 20191                          CDT                                      NaN
# 20192                          CDT                                      NaN
# 20193                          CDT                                      NaN
# 20194                          CDT                                      NaN
#
#       ActivityDepthHeightMeasure/MeasureUnitCode  \
# 1                                           feet
# 2                                           feet
# 4                                           feet
# 6                                           feet
# 7                                           feet
# 8                                           feet
# 9                                           feet
# 11                                          feet
# 13                                          feet
# 14                                          feet
# 15                                          feet
# 18                                          feet
# 19                                          feet
# 21                                          feet
# 23                                          feet
# 24                                          feet
# 25                                          feet
# 26                                          feet
# 27                                          feet
# 28                                          feet
# 29                                          feet
# 32                                          feet
# 34                                           NaN
# 36                                           NaN
# 38                                           NaN
# 39                                           NaN
# 40                                           NaN
# 41                                           NaN
# 42                                           NaN
# 43                                           NaN
# ...                                          ...
# 18863                                        NaN
# 18878                                        NaN
# 18879                                        NaN
# 18896                                        NaN
# 18897                                        NaN
# 18916                                        NaN
# 18917                                        NaN
# 18918                                        NaN
# 18919                                        NaN
# 18920                                        NaN
# 19069                                        NaN
# 19070                                        NaN
# 19093                                        NaN
# 19094                                        NaN
# 19095                                        NaN
# 19096                                        NaN
# 19098                                        NaN
# 19106                                        NaN
# 19107                                        NaN
# 19108                                        NaN
# 19109                                        NaN
# 19110                                        NaN
# 19111                                        NaN
# 19112                                        NaN
# 19113                                        NaN
# 20190                                        NaN
# 20191                                        NaN
# 20192                                        NaN
# 20193                                        NaN
# 20194                                        NaN
#
#        ActivityDepthAltitudeReferencePointText MonitoringLocationIdentifier  \
# 1                                          NaN                USGS-05427968
# 2                                          NaN                USGS-05427968
# 4                                          NaN                USGS-05427968
# 6                                          NaN                USGS-05427968
# 7                                          NaN                USGS-05427968
# 8                                          NaN                USGS-05427968
# 9                                          NaN                USGS-05427968
# 11                                         NaN                USGS-05427968
# 13                                         NaN                USGS-05427968
# 14                                         NaN                USGS-05427968
# 15                                         NaN                USGS-05427968
# 18                                         NaN                USGS-05427968
# 19                                         NaN                USGS-05427968
# 21                                         NaN                USGS-05427968
# 23                                         NaN                USGS-05427968
# 24                                         NaN                USGS-05427968
# 25                                         NaN                USGS-05427968
# 26                                         NaN                USGS-05427968
# 27                                         NaN                USGS-05427968
# 28                                         NaN                USGS-05427968
# 29                                         NaN                USGS-05427968
# 32                                         NaN                USGS-05427968
# 34                                         NaN                USGS-05428000
# 36                                         NaN                USGS-05428000
# 38                                         NaN                USGS-05428000
# 39                                         NaN                USGS-05428000
# 40                                         NaN                USGS-05428000
# 41                                         NaN                USGS-05428000
# 42                                         NaN                USGS-05428000
# 43                                         NaN                USGS-05428000
# ...                                        ...                          ...
# 18863                                      NaN             WIDNR_WQX-133456
# 18878                                      NaN             WIDNR_WQX-133456
# 18879                                      NaN             WIDNR_WQX-133456
# 18896                                      NaN             WIDNR_WQX-133456
# 18897                                      NaN             WIDNR_WQX-133456
# 18916                                      NaN             WIDNR_WQX-133456
# 18917                                      NaN             WIDNR_WQX-133456
# 18918                                      NaN             WIDNR_WQX-133456
# 18919                                      NaN             WIDNR_WQX-133456
# 18920                                      NaN             WIDNR_WQX-133456
# 19069                                      NaN             WIDNR_WQX-133464
# 19070                                      NaN             WIDNR_WQX-133464
# 19093                                      NaN             WIDNR_WQX-133464
# 19094                                      NaN             WIDNR_WQX-133464
# 19095                                      NaN             WIDNR_WQX-133464
# 19096                                      NaN             WIDNR_WQX-133464
# 19098                                      NaN             WIDNR_WQX-133464
# 19106                                      NaN             WIDNR_WQX-133464
# 19107                                      NaN             WIDNR_WQX-133464
# 19108                                      NaN             WIDNR_WQX-133464
# 19109                                      NaN             WIDNR_WQX-133464
# 19110                                      NaN             WIDNR_WQX-133535
# 19111                                      NaN             WIDNR_WQX-133535
# 19112                                      NaN             WIDNR_WQX-133535
# 19113                                      NaN             WIDNR_WQX-133535
# 20190                                      NaN             WIDNR_WQX-133552
# 20191                                      NaN             WIDNR_WQX-133552
# 20192                                      NaN             WIDNR_WQX-133552
# 20193                                      NaN             WIDNR_WQX-133552
# 20194                                      NaN             WIDNR_WQX-133552
#
#       SampleCollectionMethod/MethodIdentifier  \
# 1                                        USGS
# 2                                        USGS
# 4                                        USGS
# 6                                        USGS
# 7                                        USGS
# 8                                        USGS
# 9                                        USGS
# 11                                       USGS
# 13                                       USGS
# 14                                       USGS
# 15                                       USGS
# 18                                       USGS
# 19                                       USGS
# 21                                       USGS
# 23                                       USGS
# 24                                       USGS
# 25                                       USGS
# 26                                       USGS
# 27                                       USGS
# 28                                       USGS
# 29                                       USGS
# 32                                       USGS
# 34                                         30
# 36                                         30
# 38                                         30
# 39                                         30
# 40                                         30
# 41                                         30
# 42                                         30
# 43                                         30
# ...                                       ...
# 18863                             GRAB SAMPLE
# 18878                             GRAB SAMPLE
# 18879                             GRAB SAMPLE
# 18896                             GRAB SAMPLE
# 18897                             GRAB SAMPLE
# 18916                             GRAB SAMPLE
# 18917                             GRAB SAMPLE
# 18918                                   USEPA
# 18919                                   USEPA
# 18920                                   USEPA
# 19069                             GRAB SAMPLE
# 19070                             GRAB SAMPLE
# 19093                    SEDIMENT SINGLE GRAB
# 19094                    SEDIMENT SINGLE GRAB
# 19095                    SEDIMENT SINGLE GRAB
# 19096                    SEDIMENT SINGLE GRAB
# 19098                    SEDIMENT SINGLE GRAB
# 19106                             GRAB SAMPLE
# 19107                             GRAB SAMPLE
# 19108                             GRAB SAMPLE
# 19109                             GRAB SAMPLE
# 19110                             GRAB SAMPLE
# 19111                             GRAB SAMPLE
# 19112                             GRAB SAMPLE
# 19113                             GRAB SAMPLE
# 20190                             GRAB SAMPLE
# 20191                             GRAB SAMPLE
# 20192                             GRAB SAMPLE
# 20193                             GRAB SAMPLE
# 20194                             GRAB SAMPLE
#
#                              CharacteristicName ResultSampleFractionText  \
# 1                                        Oxygen                Dissolved
# 2                                            pH                    Total
# 4                            Temperature, water                      NaN
# 6                          Ammonia and ammonium                Dissolved
# 7                          Ammonia and ammonium                Dissolved
# 8      Inorganic nitrogen (nitrate and nitrite)                Dissolved
# 9                                       Nitrite                Dissolved
# 11                                 Hydrogen ion                    Total
# 13                                      Nitrate                Dissolved
# 14                                      Nitrate                Dissolved
# 15                                      Nitrite                Dissolved
# 18                                       Oxygen                Dissolved
# 19                                           pH                    Total
# 21                           Temperature, water                      NaN
# 23                         Ammonia and ammonium                Dissolved
# 24                         Ammonia and ammonium                Dissolved
# 25                                      Nitrate                Dissolved
# 26                                      Nitrate                Dissolved
# 27     Inorganic nitrogen (nitrate and nitrite)                Dissolved
# 28                                      Nitrite                Dissolved
# 29                                      Nitrite                Dissolved
# 32                                 Hydrogen ion                    Total
# 34                                           pH                    Total
# 36                           Temperature, water                      NaN
# 38                         Ammonia and ammonium                Dissolved
# 39                         Ammonia and ammonium                Dissolved
# 40                                      Nitrate                Dissolved
# 41                                      Nitrate                Dissolved
# 42     Inorganic nitrogen (nitrate and nitrite)                Dissolved
# 43                                      Nitrite                Dissolved
# ...                                         ...                      ...
# 18863                      Phosphate-phosphorus                    Total
# 18878                      Phosphate-phosphorus                    Total
# 18879                      Phosphate-phosphorus                    Total
# 18896                      Phosphate-phosphorus                    Total
# 18897                      Phosphate-phosphorus                    Total
# 18916                      Phosphate-phosphorus                    Total
# 18917                      Phosphate-phosphorus                    Total
# 18918                                 Turbidity                      NaN
# 18919                        Temperature, water                    Total
# 18920                          Temperature, air                    Total
# 19069                                    Carbon                    Total
# 19070                              Total solids                    Total
# 19093  Inorganic nitrogen (nitrate and nitrite)                    Total
# 19094                      Phosphate-phosphorus                    Total
# 19095                                   Ammonia                    Total
# 19096                              Total solids                    Total
# 19098                         Kjeldahl nitrogen                    Total
# 19106                      Phosphate-phosphorus                    Total
# 19107                      Phosphate-phosphorus                    Total
# 19108                      Phosphate-phosphorus                    Total
# 19109                      Phosphate-phosphorus                    Total
# 19110                      Phosphate-phosphorus                    Total
# 19111                      Phosphate-phosphorus                    Total
# 19112                      Phosphate-phosphorus                    Total
# 19113                      Phosphate-phosphorus                    Total
# 20190                      Phosphate-phosphorus                    Total
# 20191                      Phosphate-phosphorus                    Total
# 20192                      Phosphate-phosphorus                    Total
# 20193                      Phosphate-phosphorus                    Total
# 20194                      Phosphate-phosphorus                    Total
#
#       ResultMeasureValue ResultMeasure/MeasureUnitCode  \
# 1                    7.6                          mg/l
# 2                    8.6                     std units
# 4                   20.7                         deg C
# 6                  0.103                      mg/l NH4
# 7                  0.080                     mg/l as N
# 8                    NaN                           NaN
# 9                    NaN                           NaN
# 11                   NaN                           NaN
# 13                   NaN                           NaN
# 14                   NaN                           NaN
# 15                   NaN                           NaN
# 18                   0.2                          mg/l
# 19                   7.6                     std units
# 21                   9.9                         deg C
# 23                  1.07                      mg/l NH4
# 24                 0.830                     mg/l as N
# 25                 0.443                    mg/l asNO3
# 26                 0.100                     mg/l as N
# 27                 0.140                     mg/l as N
# 28                 0.131                    mg/l asNO3
# 29                 0.040                     mg/l as N
# 32               0.00003                          mg/l
# 34                   8.6                     std units
# 36                  12.5                         deg C
# 38                 0.077                      mg/l NH4
# 39                 0.060                     mg/l as N
# 40                  1.28                    mg/l asNO3
# 41                 0.290                     mg/l as N
# 42                 0.310                     mg/l as N
# 43                 0.066                    mg/l asNO3
# ...                  ...                           ...
# 18863             0.0975                          mg/l
# 18878              0.115                          mg/l
# 18879             0.0821                          mg/l
# 18896              0.117                          mg/l
# 18897              0.147                          mg/l
# 18916              0.111                          mg/l
# 18917             0.0864                          mg/l
# 18918                 32                           NTU
# 18919              24.39                         deg C
# 18920                 27                         deg C
# 19069             74500.                          ug/g
# 19070                26.                             %
# 19093                7.1                         mg/kg
# 19094              1550.                         mg/kg
# 19095               583.                         mg/kg
# 19096               23.4                             %
# 19098              *9270                         mg/kg
# 19106             0.0990                          mg/l
# 19107              0.124                          mg/l
# 19108             0.0654                          mg/l
# 19109             0.0394                          mg/l
# 19110             0.0426                          mg/l
# 19111             0.0419                          mg/l
# 19112             0.0529                          mg/l
# 19113             0.0574                          mg/l
# 20190             0.0645                          mg/l
# 20191             0.0613                          mg/l
# 20192             0.0390                          mg/l
# 20193             0.0592                          mg/l
# 20194             0.0510                          mg/l
#
#       ResultAnalyticalMethod/MethodIdentifier  \
# 1                                         NaN
# 2                                         NaN
# 4                                         NaN
# 6                                       ALGOR
# 7                                       CL035
# 8                                       CL045
# 9                                       CL040
# 11                                      ALGOR
# 13                                      ALGOR
# 14                                      ALGOR
# 15                                      ALGOR
# 18                                        NaN
# 19                                        NaN
# 21                                        NaN
# 23                                      ALGOR
# 24                                      CL035
# 25                                      ALGOR
# 26                                      ALGOR
# 27                                      CL045
# 28                                      ALGOR
# 29                                      CL040
# 32                                      ALGOR
# 34                                        NaN
# 36                                        NaN
# 38                                      ALGOR
# 39                                      CL035
# 40                                      ALGOR
# 41                                      ALGOR
# 42                                      CL045
# 43                                      ALGOR
# ...                                       ...
# 18863                                   365.1
# 18878                                   365.1
# 18879                                   365.1
# 18896                                   365.1
# 18897                                   365.1
# 18916                                   365.1
# 18917                                   365.1
# 18918                                     NaN
# 18919                                     NaN
# 18920                                     NaN
# 19069                                    9060
# 19070                                    8310
# 19093                                   353.2
# 19094                                   365.1
# 19095                                   350.1
# 19096                                  2540-G
# 19098                                   351.2
# 19106                                   365.1
# 19107                                   365.1
# 19108                                   365.1
# 19109                                   365.1
# 19110                                   365.1
# 19111                                   365.1
# 19112                                   365.1
# 19113                                   365.1
# 20190                                   365.1
# 20191                                   365.1
# 20192                                   365.1
# 20193                                   365.1
# 20194                                   365.1
#
#       ResultAnalyticalMethod/MethodIdentifierContext  \
# 1                                                NaN
# 2                                                NaN
# 4                                                NaN
# 6                                               USGS
# 7                                               USGS
# 8                                               USGS
# 9                                               USGS
# 11                                              USGS
# 13                                              USGS
# 14                                              USGS
# 15                                              USGS
# 18                                               NaN
# 19                                               NaN
# 21                                               NaN
# 23                                              USGS
# 24                                              USGS
# 25                                              USGS
# 26                                              USGS
# 27                                              USGS
# 28                                              USGS
# 29                                              USGS
# 32                                              USGS
# 34                                               NaN
# 36                                               NaN
# 38                                              USGS
# 39                                              USGS
# 40                                              USGS
# 41                                              USGS
# 42                                              USGS
# 43                                              USGS
# ...                                              ...
# 18863                                          USEPA
# 18878                                          USEPA
# 18879                                          USEPA
# 18896                                          USEPA
# 18897                                          USEPA
# 18916                                          USEPA
# 18917                                          USEPA
# 18918                                            NaN
# 18919                                            NaN
# 18920                                            NaN
# 19069                                          USEPA
# 19070                                          USEPA
# 19093                                          USEPA
# 19094                                          USEPA
# 19095                                          USEPA
# 19096                                           APHA
# 19098                                          USEPA
# 19106                                          USEPA
# 19107                                          USEPA
# 19108                                          USEPA
# 19109                                          USEPA
# 19110                                          USEPA
# 19111                                          USEPA
# 19112                                          USEPA
# 19113                                          USEPA
# 20190                                          USEPA
# 20191                                          USEPA
# 20192                                          USEPA
# 20193                                          USEPA
# 20194                                          USEPA
#
#              ResultAnalyticalMethod/MethodName ProviderName
# 1                                          NaN         NWIS
# 2                                          NaN         NWIS
# 4                                          NaN         NWIS
# 6                Computation by NWIS algorithm         NWIS
# 7                  Ammonia, wf, ASF salicylate         NWIS
# 8                NO2+NO3, wf, Cd reduction ASF         NWIS
# 9               Nitrite, wf, ASF diazotization         NWIS
# 11               Computation by NWIS algorithm         NWIS
# 13               Computation by NWIS algorithm         NWIS
# 14               Computation by NWIS algorithm         NWIS
# 15               Computation by NWIS algorithm         NWIS
# 18                                         NaN         NWIS
# 19                                         NaN         NWIS
# 21                                         NaN         NWIS
# 23               Computation by NWIS algorithm         NWIS
# 24                 Ammonia, wf, ASF salicylate         NWIS
# 25               Computation by NWIS algorithm         NWIS
# 26               Computation by NWIS algorithm         NWIS
# 27               NO2+NO3, wf, Cd reduction ASF         NWIS
# 28               Computation by NWIS algorithm         NWIS
# 29              Nitrite, wf, ASF diazotization         NWIS
# 32               Computation by NWIS algorithm         NWIS
# 34                                         NaN         NWIS
# 36                                         NaN         NWIS
# 38               Computation by NWIS algorithm         NWIS
# 39                 Ammonia, wf, ASF salicylate         NWIS
# 40               Computation by NWIS algorithm         NWIS
# 41               Computation by NWIS algorithm         NWIS
# 42               NO2+NO3, wf, Cd reduction ASF         NWIS
# 43               Computation by NWIS algorithm         NWIS
# ...                                        ...          ...
# 18863                Phosphorus by Colorimetry       STORET
# 18878                Phosphorus by Colorimetry       STORET
# 18879                Phosphorus by Colorimetry       STORET
# 18896                Phosphorus by Colorimetry       STORET
# 18897                Phosphorus by Colorimetry       STORET
# 18916                Phosphorus by Colorimetry       STORET
# 18917                Phosphorus by Colorimetry       STORET
# 18918                                      NaN       STORET
# 18919                                      NaN       STORET
# 18920                                      NaN       STORET
# 19069  Total Organic Carbon in Water and Waste       STORET
# 19070        Polynuclear Aromatic Hydrocarbons       STORET
# 19093  Nitrate-Nitrite Nitrogen by Colorimetry       STORET
# 19094                Phosphorus by Colorimetry       STORET
# 19095          Ammonia Nitrogen by Colorimetry       STORET
# 19096         Total, Fixed and Volatile Solids       STORET
# 19098   Total Kjeldahl Nitrogen by Colorimetry       STORET
# 19106                Phosphorus by Colorimetry       STORET
# 19107                Phosphorus by Colorimetry       STORET
# 19108                Phosphorus by Colorimetry       STORET
# 19109                Phosphorus by Colorimetry       STORET
# 19110                Phosphorus by Colorimetry       STORET
# 19111                Phosphorus by Colorimetry       STORET
# 19112                Phosphorus by Colorimetry       STORET
# 19113                Phosphorus by Colorimetry       STORET
# 20190                Phosphorus by Colorimetry       STORET
# 20191                Phosphorus by Colorimetry       STORET
# 20192                Phosphorus by Colorimetry       STORET
# 20193                Phosphorus by Colorimetry       STORET
# 20194                Phosphorus by Colorimetry       STORET
#
# [8308 rows x 20 columns]

# %% [markdown]
# We can write the obtained DataFrame containing the data points of Lake Mendota into a csv file of desired path.<br>
# Now we can see the data for Lake Mendota in <i>data/lake_mendota_data.csv</i>

# %%
df.to_csv('../data/lake_mendota_data.csv',index=False)
